# %%
import modin.pandas as pd
import numpy as np
import gensim
import re
import os
import ast
import nltk
from tqdm import tqdm 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.similarities import WmdSimilarity
from gensim.models import Phrases

pd.set_option('display.max_colwidth', None)

# %%
# Step 1: Load dictionary and extract keys
with open('Keyword Repository/fem_keywords_with_counts_removed.txt', 'r', encoding='utf-8') as f:
    fem_keyword_dict = ast.literal_eval(f.read())  # safely evaluate string as dictionary
FEM_WORDS = list(fem_keyword_dict.keys())

with open('Keyword Repository/masc_keywords_with_counts_removed.txt', 'r', encoding='utf-8') as f:
    masc_keyword_dict = ast.literal_eval(f.read())  # safely evaluate string as dictionary
MASC_WORDS = list(masc_keyword_dict.keys())

GENDERED_WORDS = set(MASC_WORDS + FEM_WORDS)
GENDERED_WORDS
# Out:
# {'a position with responsibility for',
#  'able to express onself clearly verbally and writing',
#  'able to make others enthusiastic',
#  'able to motivate others',
#  'achieve',
#  'achievement',
#  'achieves',
#  'achieving',
#  'active',
#  'actively',
#  'adventure',
#  'adventures',
#  'adventurous',
#  'adventurously',
#  'advice',
#  'advocate',
#  'affectionate',
#  'aggress',
#  'aggresses',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'ambassador',
#  'ambition',
#  'ambitious',
#  'aspiration',
#  'aspirational',
#  'aspirations',
#  'assert',
#  'asserting',
#  'assertings',
#  'assertion',
#  'assertive',
#  'assertives',
#  'asserts',
#  'athlete',
#  'athletic',
#  'attentive',
#  'autonomous',
#  'autonomy',
#  'boast',
#  'boasting',
#  'boasts',
#  'business sense',
#  'care',
#  'challenge',
#  'challenges',
#  'challenging',
#  'challengings',
#  'cheer',
#  'cheerfulness',
#  'child',
#  'childhood',
#  'collaborate',
#  'collaborating',
#  'collaboration',
#  'collaborative',
#  'command',
#  'commands',
#  'commercial',
#  'commercials',
#  'commit',
#  'commitment',
#  'commitment to goal',
#  'committed',
#  'communal',
#  'communication',
#  'communication skills',
#  'community',
#  'compare',
#  'compares',
#  'comparing',
#  'comparings',
#  'compassion',
#  'compassionate',
#  'compete',
#  'competes',
#  'competition',
#  'competitive',
#  'compiling',
#  'compute',
#  'computing',
#  'confident',
#  'confidently',
#  'connect',
#  'connection',
#  'conscience',
#  'conscientious',
#  'considerate',
#  'contribute',
#  'contributing',
#  'control',
#  'controlling',
#  'controls',
#  'cooperat',
#  'cooperate',
#  'cooperates',
#  'cooperation',
#  'coordinate',
#  'coordinates',
#  'coordinating',
#  'coorperative',
#  'copying',
#  'counsel',
#  'counselling',
#  'counsels',
#  'courage',
#  'courageous',
#  'creativity',
#  'credibility',
#  'credible',
#  'customer service oriented',
#  'decide',
#  'decides',
#  'decision',
#  'decisions',
#  'decisive',
#  'decisively',
#  'decisives',
#  'defend',
#  'defending',
#  'defends',
#  'defensive',
#  'deliver',
#  'delivering',
#  'delivers',
#  'demand',
#  'demanding',
#  'demands',
#  'depend',
#  'dependable',
#  'dependence',
#  'detail oriented',
#  'detail-oriented',
#  'determination',
#  'determine',
#  'determined',
#  'determines',
#  'dialogue',
#  'direct',
#  'directed',
#  'directing',
#  'direction',
#  'directs',
#  'diverting',
#  'dominance',
#  'dominant',
#  'dominants',
#  'dominate',
#  'dominates',
#  'drive',
#  'drives',
#  'driving',
#  'emotiona',
#  'empath',
#  'empathy',
#  'empower',
#  'enable',
#  'enables',
#  'enabling',
#  'encourage',
#  'encouragement',
#  'enthusiasm',
#  'entrepreneur',
#  'entrepreneurial',
#  'establish',
#  'excellence',
#  'excellent',
#  'excellently',
#  'exceptional',
#  'exceptionally',
#  'feed',
#  'feeding',
#  'feeds',
#  'feminine',
#  'flatterable',
#  'flexibility',
#  'force',
#  'forced',
#  'forceful',
#  'forces',
#  'forcing',
#  'gentle',
#  'goal-oriented',
#  'goal-orientedness',
#  'good contactual skills',
#  'greed',
#  'greedy',
#  'handle',
#  'handles',
#  'handling',
#  'handlings',
#  'headstrong',
#  'headstrongs',
#  'heart',
#  'helpful talents',
#  'helpfulness',
#  'hierarchy',
#  'honest',
#  'honestly communicating',
#  'honesty',
#  'hostile',
#  'hostility',
#  'ideal',
#  'implement',
#  'implusive',
#  'implusively',
#  'implusiveness',
#  'implusives',
#  'impressive',
#  'impressively',
#  'independence',
#  'independent',
#  'independently',
#  'individual',
#  'individualistic',
#  'individuality',
#  'individually',
#  'individuals',
#  'influence',
#  'influencing',
#  'influential',
#  'influentials',
#  'initiative',
#  'initiatives',
#  'instruct',
#  'instructing',
#  'instructs',
#  'intellect',
#  'intellects',
#  'intellectual',
#  'intellectually',
#  'intelligence',
#  'interdependen',
#  'interdependence',
#  'interpersona',
#  'interpersonal',
#  'introduce',
#  'intuition',
#  'intuitive',
#  'kind',
#  'kinship',
#  'listen',
#  'listening',
#  'listens',
#  'logic',
#  'logical',
#  'logically',
#  'logics',
#  'loyal',
#  'loyalty',
#  'manipulating',
#  'manipulation',
#  'masculine',
#  'masculines',
#  'masculinity',
#  'mentor',
#  'mentoring',
#  'modesty',
#  'motivate',
#  'motivates',
#  'motivating',
#  'motivation',
#  'nag',
#  'negotiate',
#  'negotiates',
#  'negotiating',
#  'negotiation',
#  'negotiations',
#  'nurtur',
#  'nurturing',
#  'objective',
#  'objectively',
#  'objectives',
#  'objectivity',
#  'offbearing',
#  'operate',
#  'operating',
#  'opine',
#  'opinion',
#  'opinionated',
#  'opinions',
#  'organizational',
#  'organize',
#  'outspoken',
#  'outspokenness',
#  'outstanding',
#  'participate',
#  'participates',
#  'participating',
#  'people oriented',
#  'perform',
#  'performing',
#  'performs',
#  'persist',
#  'persistence',
#  'persistent',
#  'persists',
#  'personal',
#  'persuading',
#  'pleasant',
#  'pleasure',
#  'polite',
#  'power',
#  'powerful',
#  'powering',
#  'powers',
#  'precision work',
#  'principle',
#  'principled',
#  'principles',
#  'professional',
#  'professionality',
#  'professionally',
#  'proud',
#  'proudly',
#  'push',
#  'pushes',
#  'pushing',
#  'pushings',
#  'quality',
#  'quiet',
#  'quietness',
#  'rapport',
#  'rational',
#  'rationality',
#  'rationally',
#  'reckless',
#  'recklessly',
#  'recklessness',
#  'recruit',
#  'recruiting',
#  'recruits',
#  'relation',
#  'reputation',
#  'resolution',
#  'resolutions',
#  'respon',
#  'response',
#  'responsibility',
#  'responsible',
#  'robust',
#  'role model',
#  'seize',
#  'seizes',
#  'self confident',
#  'self-confidence',
#  'self-confident',
#  'self-reliance',
#  'self-reliant',
#  'self-reliantly',
#  'self-sufficiency',
#  'self-sufficient',
#  'self-sufficiently',
#  'sense',
#  'sensible',
#  'sensitiv',
#  'sensitive',
#  'sensitivity',
#  'serve',
#  'servicing',
#  'serving',
#  'setting up',
#  'setting-up',
#  'shape',
#  'shapes',
#  'share',
#  'shares',
#  'sharing',
#  'sincere',
#  'sincerity',
#  'sociable',
#  'social',
#  'social responsibility',
#  'society',
#  'speaking-signaling',
#  'strategic',
#  'strategically',
#  'strategics',
#  'strategies',
#  'strategise',
#  'strategize',
#  'strategy',
#  'stubborn',
#  'stubbornness',
#  'submissive',
#  'success',
#  'successful',
#  'successfully',
#  'superior',
#  'superiority',
#  'superiors',
#  'supervise',
#  'supervising',
#  'supervize',
#  'supervizing',
#  'sustainability',
#  'sustainability orientation',
#  'sympath',
#  'sympathy',
#  'synthesise',
#  'synthesising',
#  'synthesize',
#  'synthesizing',
#  'task oriented',
#  'task-oriented',
#  'team spirit',
#  'teamwork',
#  'teamworker',
#  'tender',
#  'tenderness',
#  'tending',
#  'together',
#  'togetherness',
#  'transform',
#  'transformative',
#  'transforming',
#  'transforms',
#  'trust',
#  'trusting',
#  'values',
#  'warm',
#  'whin',
#  'whining',
#  'win',
#  'winner',
#  'winning',
#  'wins',
#  'work closely',
#  'world class',
#  'yield',
#  'yielding'}

# %%
def vectorize_text(tokens, w2v_model):
    # Vectorize the tokens (including bigrams)
    vectors = [w2v_model.wv[word] for word in tokens if word in w2v_model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(w2v_model.vector_size)

# %%
# Parameters
top_n = 10  # Number of recommendations
num_best = top_n  # Just for clarity

# %%
jobs_data_dir = "../Job Data/"
dataframes = []
# Read all files in the directory
for file_name in os.listdir(jobs_data_dir):
    if '2024' in file_name: 
        print(file_name)
        file_path = os.path.join(jobs_data_dir, file_name)
        tmp_df = pd.read_csv(file_path, usecols = ['jobPostingId', 'title', 'description', 'tokens', 'gender_category'])
        tmp_df = tmp_df.dropna(how='any')
        dataframes.append(tmp_df)
job_postings_df = pd.concat(dataframes)
print(len(job_postings_df))
job_postings_df.head()
# Out:
# annotated_data_2024_batch_2_removed_words_tokenized.csv
# 2025-04-30 18:01:29,707	INFO worker.py:1841 -- Started a local Ray instance.
# annotated_data_2024_removed_words_tokenized.csv
# 77975
#    jobPostingId                                           title  \
# 0    3823301365      Python Full Stack Developer/Lead/Architect
# 1    3823301077                  Senior Data Engineer - w2 only
# 2    3823301053                     Retail Front End Supervisor
# 3    3823301005              Front-end Software Engineer, LATAM
# 4    3823300903  Senior Python Developer with DevOps Experience
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Skills- Python, Django, React/AngularExperience- 4+ yrsLocation- Hyderabad\nJob Description-\nâ¢ Python + Django, Angular/React Develop, and maintain robust, scalable backend systems using Python.â¢ Ensure technology solutions align with company architectural standards.â¢ Collaborate seamlessly with cross-functional teams for the integration of platform services.â¢ Foster close collaboration with frontend developers, ensuring a harmonious backend-frontend integration.â¢ Proactively identify and resolve issues promptly.â¢ Strong full-stack development skills in Python, including expertise in frameworks like Django (Expert).â¢ Experience with microservice architecture, end-to-end UI/API integration, and knowledge of API protocols like REST, gRPC, and GraphQL (Advanced).â¢ Knowledge of Caching technologies and DBMS technologies like MySQL, PostGres, MongoDB, and database schema design (Advanced).â¢ Strong problem-solving, communication, and organizational skills (Advanced).â¢ Proficiency in UI modern x like AngularJS or ReactJS (Intermediate).â¢ Proficient in drafting coding practices and designing highly scalable, secure, and maintainable software solutions (Intermediate).â¢ Experience in building large-scale platforms handling real-time complex transactions and troubleshooting distributed systems (Intermediate).
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Expertise:8+ years of relevant industry experience with a BS/MastersExperience with distributed processing technologies and frameworks, such as Hadoop, Spark, Kafka, and distributed storage systems (e.g., HDFS, S3)Demonstrated ability to analyze large data sets to identify gaps and inconsistencies, provide data insights, and advance effective product solutionsExpertise with ETL schedulers such as Apache Airflow, Luigi, Oozie, AWS Glue or similar frameworksSolid understanding of data warehousing concepts and hands-on experience with relational databases (e.g., PostgreSQL, MySQL) and columnar databases (e.g., Redshift, BigQuery, HBase, ClickHouse)Excellent written and verbal communication skillsA Typical Day:Design, build, and maintain robust and efficient data pipelines that collect, process, and store data from various sources, including user interactions, financial details, and external data feeds.Develop data models that enable the efficient analysis and manipulation of data for merchandising optimization. Ensure data quality, consistency, and accuracy.Build scalable data pipelines (SparkSQL & Scala) leveraging Airflow scheduler/executor frameworkCollaborate with cross-functional teams, including Data Scientists, Product Managers, and Software Engineers, to define data requirements, and deliver data solutions that drive merchandising and sales improvements.Contribute to the broader Data Engineering community at Airbnb to influence tooling and standards to improve culture and productivityImprove code and data quality by leveraging and contributing to internal tools to automatically detect and mitigate issues.\n
# 2  LOCATION 1130 Newport Avenue Attleboro MA US 02703\n\nOverview\n\nAt Burlington, we embrace the many facets of diversity that strengthen our communities where we live and work every day. If you want to grow your retail career with a caring and inclusive organization, come join us as a Burlington Stores Full-Time Customer Service Supervisor or Full-Time Selling Floor Supervisor!\n\nAs a Retail Front End Supervisor, youâll be an integral part of the store leadership team, working closely with Store Management in the areas of Merchandising, Customer Service, Operations, and Human Resources. This leadership position is the stepping-stone to a management role within our expanding organization. Are you a self-starter with the ability to supervise store operations efficiently and effectively? If you are a proven leader who understands the value of building strong teams and partnerships to drive results, this is the right opportunity for you!\n\nAt Burlington, we live by our Core Values:\n\nDrive ResultsTrust & Respect Each OtherBuild Teams & Partnerships\n\nBurlington Benefits:\n\nGrowth OpportunitiesCompetitive PayFlexible Hours15-30% Associate DiscountMedical, Dental, and Vision CoverageEmployee Assistance ProgramLife and Disability InsurancePaid Time OffPaid Holidays401 (k)\n\nKey Responsibilities:\n\nSupervise all store functions and associates while in the role of Manager on DutyMaximize sales results through training, developing, and coaching of direct reportsPromote safety for both our customers and associates by adhering to company guidelinesCultivate a diverse culture based on teamwork and collaborationSolve issues/concerns, making informed decisions and supervising the front-end operations to ensure all Burlington customers are provided with exceptional, friendly, and professional customer service at all timesReinforce our company Asset Protection strategies to eliminate shortageAssist in recruiting, interviewing, and onboarding new associatesParticipate in weekly workload planning meetingsDrives Community Relations participation through company programs and partnershipsCoordinate meal and break periods and monitors schedule adherence\n\nRequirements:\n\nAt least 1 year of supervisory experience within an off-price, big box or a specialty environmentStrong interpersonal skills with a positive and engaging attitudeAbility to work a full-time schedule including nights, weekends and holidays as requiredAbility to move/handle/lift store merchandise weighing 40 lbs. or more, as well as the ability to stand and walk for extended periods of time\n\nAt Burlington weâre opening more stores nationwide to provide you with even more locations to enjoy our amazing prices on the brands and styles you love. As we grow, you can too through a variety of training and development opportunities!\n\nCome join our team. Youâre going to like it here!\n\nYou will enjoy a competitive wage, flexible hours, and an associate discount. Burlington's benefits package includes medical, dental, and vision coverage including life and disability insurance. Full time associates may also be eligible for up to 12 days of paid time off annually, up to 8 paid holidays, paid sick time in accordance with applicable law, and a 401(k) plan. We are a rapidly growing brand and provide a variety of training and development opportunities so our associates can grow with us.\n\nOur store teams work hard and have fun together! Burlington associates make a difference in the lives of customers, colleagues, and the communities where we live and work every day. Burlington Stores, Inc. is an equal opportunity employer committed to workplace diversity.\n\nLocation US-MA-Attleboro\n\nPosting Number 2024-214348\n\nAddress 1130 Newport Avenue\n\nZip Code 02703\n\nWorkplace Type On-Site\n\nPosition Type Regular Full-Time\n\nCareer Site Category Store Associate\n\nPosition Category Store Supervisor\n\nEvergreen Yes\n\nMin USD $17.50/Hour\n\nMid USD $19.50/Hour
# 3                                                                                                                Build the platform behind the most extensive startup engagement programs in the world. YouNoodle is looking for a talented Front-end engineer to join our global team of coders, hackers, and data geeks. We are helping tens of thousands of startups move forward on our global startup programs platform and working hard to build the worldâs largest innovation engine. We are looking for a promising engineer to help scale our existing products and build tomorrowâs next big thing. \nWe are looking for someone who knows their way around JavaScript and React. Our codebase is very structured and neat, and we want to keep it that way. Weâre looking for someone who can dive in and take responsibility where needed, whether speeding up the site or building new user-facing features. Sometimes, you will work on a new platform or language, and we would love someone who is fearless, versatile, curious, and can jump right in to get the job done. You will be given a lot of independence in your work and a real opportunity to influence the product meaningfully.\n# Role Description:\nThis role involves working closely with our product & engineering team on our web SaaS product, YouNoodle Compete. You will be helping build new features, squash bugs, and test; therefore, investigation and logic should come naturally to you as they do to Sherlock. You will help and assist both technical & non-technical noodlers with product issues and requests.\n# Desired Skills and Experience:\nYou are the perfect front engineer if you have/are:- 3+ years of experience as a front engineer. - Proficient in React framework and up-to-date with the latest version and best practices.- Experience with unit testing and code linting.- Experienced with Design framework (Material Design, Tailwind). - Have a passion for neat, maintainable, and testable code.- Love solving complex engineering problems and challenges.- Disciplined enough to accommodate a flexible & remote workflow.- Think that collaboration is more important than being right.- Are curious and have a deep desire to learn.- Fluent in English.\n# Nice to have:\n- Strong understanding of AngularJS routing and state management. - Firebase- Laravel or PHP- Experience as a backend/full stack engineer.- Familiarity with Turborepo. \n\n# Company and Culture:\nYouNoodle is a Silicon Valley-based virtual startup engagement company. Since 2010, our technology has powered startup programs run by both governments and corporations, such as Amazon and The World Bank.Through our technology, accelerators are not bound by physical spaces, borders, visa requirements, and organizations. They can run global programs virtually, including access to 200,000 startups and 25,000 experts from 180 countries on YouNoodle.\nThe YouNoodle team is passionate about the global startup revolution. We are tied together by mutual respect for each others' differences and a strong willingness to step up for your fellow Noodler. Our company culture is very open, inclusive, hard-working, competitive, fun and happy! Our small team boasts incredible geographic and cultural diversity. We meet at least once a year for a global retreat, and you often find us engaged in competitive battles of all sorts. But more than anything, we ensure our clients, partners, and startups succeed in their endeavors.\nIf you believe you are the right fit for this role, please apply at this link: https://bit.ly/FSLATAM\nOr scan this code:\n\n# Our Commitment to Diversity and InclusionWeâre committed to growing and empowering a more inclusive community within our company, industry, and cities. Thatâs why we hire and cultivate diverse teams of the best and brightest from all backgrounds, experiences, and perspectives. We believe that true innovation happens when everyone has room at the table and the tools, resources, and opportunities to thrive.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Tittle: Python Developer with DevOps ExperienceLocation: Austin TX (day one Onsite)Full TimeJD:Must Have: â¢ Minimum of 4-5 years of experience in building solutions in Python.â¢ Experience developing RESTful APIs and micro-services in Python.â¢ Experience in developing applications with MongoDB (pymongo).â¢ Experience working with Container technologies including Docker and Kubernetes.â¢ Experience developing tools to improve Developer efficiency and Software Quality processes.â¢ Experience designing and implementing tests including unit tests and integration tests.â¢ Knowledge of infrastructure as code such as AWS CloudFormation, GCP Deployment, or Terraform.â¢ Knowledge of CI/CD frameworks.â¢ Excellent oral/written communication skills.â¢ Ability to work independently with minimal oversight.â¢ Willingness to pick up occasional tasks in Golang.â¢ Ability to follow team software development lifecycle including using Git, following testing requirements, and completing pull requests. Nice to Have: â¢ Experience using container orchestration platforms like Kubernetes, EKS, ECS, or GKEâ¢ Hands-on experience in building and deploying software in at least one of the major public cloud providers (such as Amazon Web Services, Google Cloud Platform)â¢ Experience building and maintaining CI/CD environments.â¢ Experience with test driven design.â¢ Knowledge in risk management and understanding risk profile for a given application and its infrastructureâ¢ Experience architecting and developing applications in Cloud Native Infrastructure based on 12 Factor application concepts.
#
#   gender_category  \
# 0             fem
# 1         neutral
# 2            masc
# 3            masc
# 4            masc
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   tokens
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ['python', 'full', 'stack', 'python', 'django', 'hyderabad', 'job', 'python', 'django', 'develop', 'maintain', 'robust', 'scalable', 'backend', 'system', 'using', 'ensure', 'technology', 'solution', 'align', 'company', 'architectural', 'collaborate', 'seamlessly', 'team', 'integration', 'platform', 'foster', 'close', 'collaboration', 'frontend', 'developer', 'ensuring', 'harmonious', 'proactively', 'identify', 'resolve', 'issue', 'strong', 'development', 'skill', 'python', 'including', 'expertise', 'framework', 'like', 'django', 'expert', 'experience', 'microservice', 'architecture', 'integration', 'knowledge', 'api', 'protocol', 'like', 'rest', 'grpc', 'graphql', 'advanced', 'knowledge', 'caching', 'technology', 'dbms', 'technology', 'like', 'mysql', 'postgres', 'mongodb', 'database', 'schema', 'design', 'advanced', 'strong', 'communication', 'organizational', 'skill', 'advanced', 'proficiency', 'ui', 'modern', 'x', 'like', 'angularjs', 'reactjs', 'intermediate', 'proficient', 'drafting', 'coding', 'practice', 'designing', 'highly', 'scalable', 'secure', 'maintainable', 'software', 'solution', 'intermediate', 'experience', 'building', 'platform', 'handling', 'complex', 'transaction', 'troubleshooting', 'distributed', 'system', 'intermediate']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ['senior', 'data', 'engineer', 'year', 'relevant', 'industry', 'experience', 'distributed', 'processing', 'technology', 'framework', 'hadoop', 'spark', 'kafka', 'distributed', 'storage', 'system', 'hdfs', 'demonstrated', 'ability', 'analyze', 'large', 'data', 'set', 'identify', 'gap', 'inconsistency', 'provide', 'data', 'insight', 'advance', 'effective', 'product', 'solutionsexpertise', 'etl', 'scheduler', 'apache', 'airflow', 'luigi', 'oozie', 'aws', 'glue', 'similar', 'frameworkssolid', 'understanding', 'data', 'warehousing', 'concept', 'experience', 'relational', 'database', 'postgresql', 'mysql', 'columnar', 'database', 'redshift', 'bigquery', 'hbase', 'clickhouse', 'excellent', 'written', 'verbal', 'communication', 'skillsa', 'typical', 'day', 'design', 'build', 'maintain', 'robust', 'efficient', 'data', 'pipeline', 'collect', 'process', 'store', 'data', 'various', 'source', 'including', 'user', 'interaction', 'financial', 'detail', 'external', 'data', 'data', 'model', 'enable', 'efficient', 'analysis', 'manipulation', 'data', 'merchandising', 'optimization', 'ensure', 'data', 'quality', 'consistency', 'scalable', 'data', 'pipeline', 'sparksql', 'scala', 'leveraging', 'airflow', 'frameworkcollaborate', 'team', 'including', 'data', 'scientist', 'product', 'manager', 'software', 'engineer', 'define', 'data', 'requirement', 'deliver', 'data', 'solution', 'drive', 'merchandising', 'sale', 'broader', 'data', 'engineering', 'community', 'airbnb', 'influence', 'tooling', 'standard', 'improve', 'culture', 'productivityimprove', 'code', 'data', 'quality', 'leveraging', 'contributing', 'internal', 'tool', 'automatically', 'detect', 'mitigate', 'issue']
# 2  ['retail', 'front', 'end', 'supervisor', 'location', 'newport', 'avenue', 'attleboro', 'u', 'overview', 'burlington', 'embrace', 'many', 'facet', 'diversity', 'strengthen', 'community', 'live', 'work', 'every', 'day', 'want', 'grow', 'retail', 'career', 'caring', 'inclusive', 'organization', 'come', 'join', 'u', 'burlington', 'store', 'customer', 'service', 'supervisor', 'selling', 'floor', 'supervisor', 'retail', 'front', 'end', 'supervisor', 'integral', 'part', 'store', 'leadership', 'team', 'working', 'closely', 'store', 'management', 'area', 'merchandising', 'customer', 'service', 'operation', 'human', 'resource', 'leadership', 'position', 'management', 'role', 'within', 'expanding', 'organization', 'ability', 'supervise', 'store', 'operation', 'efficiently', 'effectively', 'proven', 'leader', 'understands', 'value', 'building', 'strong', 'team', 'partnership', 'drive', 'result', 'right', 'opportunity', 'burlington', 'live', 'core', 'value', 'drive', 'resultstrust', 'respect', 'otherbuild', 'team', 'partnership', 'burlington', 'benefit', 'growth', 'opportunitiescompetitive', 'payflexible', 'associate', 'discountmedical', 'dental', 'vision', 'coverageemployee', 'assistance', 'programlife', 'disability', 'insurancepaid', 'time', 'offpaid', 'k', 'key', 'responsibility', 'supervise', 'store', 'function', 'associate', 'role', 'manager', 'dutymaximize', 'sale', 'result', 'training', 'developing', 'coaching', 'direct', 'reportspromote', 'safety', 'customer', 'associate', 'adhering', 'company', 'guidelinescultivate', 'diverse', 'culture', 'based', 'teamwork', 'collaborationsolve', 'making', 'informed', 'decision', 'supervising', 'operation', 'ensure', 'burlington', 'customer', 'provided', 'exceptional', 'friendly', 'professional', 'customer', 'service', 'timesreinforce', 'company', 'asset', 'protection', 'strategy', 'eliminate', 'shortageassist', 'recruiting', 'interviewing', 'onboarding', 'new', 'associatesparticipate', 'weekly', 'workload', 'planning', 'meetingsdrives', 'community', 'relation', 'participation', 'company', 'program', 'partnershipscoordinate', 'meal', 'break', 'period', 'monitor', 'schedule', 'adherence', 'requirement', 'least', 'year', 'supervisory', 'experience', 'within', 'big', 'box', 'specialty', 'environmentstrong', 'interpersonal', 'skill', 'positive', 'engaging', 'attitudeability', 'work', 'schedule', 'including', 'night', 'weekend', 'holiday', 'requiredability', 'store', 'merchandise', 'weighing', 'lb', 'well', 'ability', 'stand', 'walk', 'extended', 'period', 'time', 'burlington', 'opening', 'store', 'nationwide', 'provide', 'even', 'location', 'enjoy', 'amazing', 'price', 'brand', 'style', 'love', 'grow', 'variety', 'training', 'development', 'opportunity', 'come', 'join', 'team', 'going', 'like', 'enjoy', 'competitive', 'wage', 'flexible', 'hour', 'associate', 'discount', 'burlington', 'benefit', 'package', 'includes', 'medical', 'dental', 'vision', 'coverage', 'including', 'life', 'disability', 'insurance', 'full', 'time', 'associate', 'may', 'also', 'eligible', 'day', 'paid', 'time', 'annually', 'paid', 'holiday', 'paid', 'sick', 'time', 'accordance', 'applicable', 'law', 'k', 'plan', 'rapidly', 'growing', 'brand', 'provide', 'variety', 'training', 'development', 'opportunity', 'associate', 'grow', 'u', 'store', 'team', 'work', 'hard', 'fun', 'together', 'burlington', 'associate', 'make', 'difference', 'life', 'customer', 'colleague', 'community', 'live', 'work', 'every', 'day', 'burlington', 'store', 'equal', 'opportunity', 'employer', 'committed', 'workplace', 'diversity', 'location', 'posting', 'number', 'address', 'newport', 'avenue', 'zip', 'code', 'workplace', 'type', 'position', 'type', 'regular', 'career', 'site', 'category', 'store', 'associate', 'position', 'category', 'store', 'supervisor', 'evergreen', 'yes', 'min', 'usd', 'mid', 'usd']
# 3                                                                                                                                                                                                                                                                                                                                                                                                         ['software', 'engineer', 'latam', 'build', 'platform', 'behind', 'extensive', 'startup', 'engagement', 'program', 'world', 'younoodle', 'looking', 'talented', 'engineer', 'join', 'global', 'team', 'coder', 'hacker', 'data', 'geek', 'helping', 'ten', 'thousand', 'startup', 'move', 'forward', 'global', 'startup', 'program', 'platform', 'working', 'hard', 'build', 'largest', 'innovation', 'engine', 'looking', 'promising', 'engineer', 'help', 'scale', 'existing', 'product', 'build', 'next', 'big', 'thing', 'looking', 'someone', 'know', 'way', 'around', 'javascript', 'react', 'codebase', 'structured', 'neat', 'want', 'keep', 'way', 'looking', 'someone', 'dive', 'take', 'responsibility', 'needed', 'whether', 'speeding', 'site', 'building', 'new', 'feature', 'sometimes', 'work', 'new', 'platform', 'language', 'would', 'love', 'someone', 'fearless', 'versatile', 'curious', 'jump', 'right', 'get', 'job', 'done', 'given', 'lot', 'independence', 'work', 'real', 'opportunity', 'influence', 'product', 'meaningfully', 'role', 'description', 'role', 'involves', 'working', 'closely', 'product', 'engineering', 'team', 'web', 'saas', 'product', 'younoodle', 'compete', 'helping', 'build', 'new', 'feature', 'squash', 'bug', 'test', 'therefore', 'investigation', 'logic', 'come', 'naturally', 'sherlock', 'help', 'assist', 'technical', 'noodlers', 'product', 'issue', 'request', 'desired', 'skill', 'experience', 'perfect', 'front', 'engineer', 'year', 'experience', 'front', 'engineer', 'proficient', 'react', 'framework', 'latest', 'version', 'best', 'experience', 'unit', 'testing', 'code', 'experienced', 'design', 'framework', 'material', 'design', 'tailwind', 'passion', 'neat', 'maintainable', 'testable', 'love', 'solving', 'complex', 'engineering', 'problem', 'disciplined', 'enough', 'accommodate', 'flexible', 'remote', 'think', 'collaboration', 'important', 'curious', 'deep', 'desire', 'fluent', 'english', 'nice', 'strong', 'understanding', 'angularjs', 'routing', 'state', 'management', 'laravel', 'experience', 'stack', 'familiarity', 'turborepo', 'company', 'culture', 'younoodle', 'silicon', 'virtual', 'startup', 'engagement', 'company', 'since', 'technology', 'powered', 'startup', 'program', 'run', 'government', 'corporation', 'amazon', 'world', 'technology', 'accelerator', 'bound', 'physical', 'space', 'border', 'visa', 'requirement', 'organization', 'run', 'global', 'program', 'virtually', 'including', 'access', 'startup', 'expert', 'country', 'younoodle', 'younoodle', 'team', 'passionate', 'global', 'startup', 'revolution', 'tied', 'together', 'mutual', 'respect', 'others', 'difference', 'strong', 'willingness', 'step', 'fellow', 'noodler', 'company', 'culture', 'open', 'inclusive', 'competitive', 'fun', 'happy', 'small', 'team', 'boast', 'incredible', 'geographic', 'cultural', 'diversity', 'meet', 'least', 'year', 'global', 'retreat', 'often', 'find', 'u', 'engaged', 'competitive', 'battle', 'sort', 'anything', 'ensure', 'client', 'partner', 'startup', 'succeed', 'endeavor', 'believe', 'right', 'fit', 'role', 'please', 'apply', 'link', 'http', 'scan', 'code', 'commitment', 'diversity', 'committed', 'growing', 'empowering', 'inclusive', 'community', 'within', 'company', 'industry', 'city', 'hire', 'cultivate', 'diverse', 'team', 'best', 'brightest', 'background', 'experience', 'perspective', 'believe', 'true', 'innovation', 'happens', 'everyone', 'room', 'table', 'tool', 'resource', 'opportunity', 'thrive']
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ['senior', 'python', 'developer', 'devops', 'experience', 'tittle', 'python', 'developer', 'devops', 'experiencelocation', 'austin', 'tx', 'day', 'one', 'onsite', 'full', 'timejd', 'must', 'minimum', 'year', 'experience', 'building', 'solution', 'experience', 'developing', 'restful', 'apis', 'experience', 'developing', 'application', 'mongodb', 'pymongo', 'experience', 'working', 'container', 'technology', 'including', 'docker', 'experience', 'developing', 'tool', 'improve', 'developer', 'efficiency', 'software', 'quality', 'experience', 'designing', 'implementing', 'test', 'including', 'unit', 'test', 'integration', 'knowledge', 'infrastructure', 'code', 'aws', 'cloudformation', 'gcp', 'deployment', 'knowledge', 'excellent', 'communication', 'ability', 'work', 'independently', 'minimal', 'willingness', 'pick', 'occasional', 'task', 'ability', 'follow', 'team', 'software', 'development', 'lifecycle', 'including', 'using', 'git', 'following', 'testing', 'requirement', 'completing', 'pull', 'request', 'nice', 'experience', 'using', 'container', 'orchestration', 'platform', 'like', 'kubernetes', 'eks', 'ec', 'experience', 'building', 'deploying', 'software', 'least', 'one', 'major', 'public', 'cloud', 'provider', 'amazon', 'web', 'service', 'google', 'cloud', 'platform', 'experience', 'building', 'maintaining', 'experience', 'test', 'driven', 'knowledge', 'risk', 'management', 'understanding', 'risk', 'profile', 'given', 'application', 'experience', 'architecting', 'developing', 'application', 'cloud', 'native', 'infrastructure', 'based', 'factor', 'application', 'concept']
# (_remote_exec_single_chain pid=35296) 'Word2Vec' object is not subscriptable. fn=<function Map.register.<locals>.caller.<locals>.<lambda> at 0x000001E6C6BBE8E0>, obj=                                                 tokens
# ...
# (_remote_exec_multi_chain pid=7140) 20113    3881514945  ...  ['knowledge', 'management', 'analyst', 'ii', '...
# (_remote_exec_multi_chain pid=7140) 20114    3881514921  ...  ['senior', 'c', 'developer', 'technical', 'arc...
# (_remote_exec_multi_chain pid=7140) 20115    3881514663  ...  ['c', 'foundry', 'consultant', 'summary', 'pos...
# (_remote_exec_multi_chain pid=7140) 27561    3966999534  ...  ['software', 'developer', 'sr', 'oracle', 'rea...
# (_remote_exec_multi_chain pid=7140) 27562    3966999474  ...  ['senior', 'tableau', 'developer', 'people', '...
# (_remote_exec_multi_chain pid=7140) 27563    3966997668  ...  ['software', 'development', 'engineer', 'job',...
# (_remote_exec_multi_chain pid=7140) 27564    3966996732  ...  ['software', 'development', 'engineer', 'intec...
# (_remote_exec_multi_chain pid=7140) 27565    3966995058  ...  ['ui', 'developer', 'company', 'description', ...
# (_remote_exec_multi_chain pid=7140)
# (_remote_exec_multi_chain pid=36596) 34969  ['waterbury', 'mobile', 'app', 'development', ...
# (_remote_exec_multi_chain pid=36596) 34970  ['peoria', 'aws', 'certified', 'solution', 'ar...
# (_remote_exec_multi_chain pid=36596) 34971  ['beaumont', 'computer', 'programming', 'tutor...
# (_remote_exec_multi_chain pid=36596) 34972  ['senior', 'software', 'engineer', 'morgan', '...
# (_remote_exec_multi_chain pid=36596) 34973  ['lansing', 'comptia', 'tutor', 'lansing', 'co...
# (_remote_exec_multi_chain pid=36596) 40829  ['delphi', 'application', 'developer', 'must',...
# (_remote_exec_multi_chain pid=36596) 40830  ['senior', 'mongodb', 'developer', 'job', 'tit...
# (_remote_exec_multi_chain pid=36596) 40831  ['chief', 'enterprise', 'architect', 'job', 'd...
# (_remote_exec_multi_chain pid=36596) 40832  ['scada', 'software', 'engineer', 'dice', 'lea...
# (_remote_exec_multi_chain pid=36596) 40833  ['senior', 'software', 'engineer', 'python', '...
# (_remote_exec_multi_chain pid=36596)
# (_remote_exec_multi_chain pid=36596) 34969    3852155407  ...  ['waterbury', 'mobile', 'app', 'development', ...
# (_remote_exec_multi_chain pid=36596) 34970    3852155353  ...  ['peoria', 'aws', 'certified', 'solution', 'ar...
# (_remote_exec_multi_chain pid=36596) 34971    3852155119  ...  ['beaumont', 'computer', 'programming', 'tutor...
# (_remote_exec_multi_chain pid=36596) 34972    3852154873  ...  ['senior', 'software', 'engineer', 'morgan', '...
# (_remote_exec_multi_chain pid=36596) 34973    3852153535  ...  ['lansing', 'comptia', 'tutor', 'lansing', 'co...
# (_remote_exec_multi_chain pid=36596) 40829    4052201035  ...  ['delphi', 'application', 'developer', 'must',...
# (_remote_exec_multi_chain pid=36596) 40830    4052200873  ...  ['senior', 'mongodb', 'developer', 'job', 'tit...
# (_remote_exec_multi_chain pid=36596) 40831    4052200543  ...  ['chief', 'enterprise', 'architect', 'job', 'd...
# (_remote_exec_multi_chain pid=36596) 40832    4052200291  ...  ['scada', 'software', 'engineer', 'dice', 'lea...
# (_remote_exec_multi_chain pid=36596) 40833    4052200279  ...  ['senior', 'software', 'engineer', 'python', '...
# (_remote_exec_multi_chain pid=36596)
# (_remote_exec_multi_chain pid=12480) 1     ['markdown', 'summary', 'dynamic', 'technology...
# (_remote_exec_multi_chain pid=12480)
# (_remote_exec_multi_chain pid=12480) 1     ```markdown\n**Summary**  \nDynamic and result...  ...  ['markdown', 'summary', 'dynamic', 'technology...
# (_remote_exec_multi_chain pid=12480) 1231  ```plaintext\n**Summary**\nDynamic and results...  ...  ['plaintext', 'summary', 'dynamic', 'software'...
# (_remote_exec_multi_chain pid=12480)
# (_remote_exec_multi_chain pid=404) 27990  ['full', 'stack', 'engineer', 'sdk', 'node', '...
# (_remote_exec_multi_chain pid=404) 27991  ['system', 'administrator', 'role', 'system', ...
# (_remote_exec_multi_chain pid=404) 27992  ['devops', 'engineer', 'welcome', 'hastings', ...
# (_remote_exec_multi_chain pid=404) 27993  ['system', 'administrator', 'role', 'system', ...
# (_remote_exec_multi_chain pid=404) 27994  ['machine', 'learning', 'lead', 'analyst', 'ev...
# (_remote_exec_multi_chain pid=404) 37136  ['sap', 'digital', 'payment', 'integration', '...
# (_remote_exec_multi_chain pid=404) 37137  ['full', 'time', 'oracle', 'hcm', 'program', '...
# (_remote_exec_multi_chain pid=404) 37138  ['manager', 'network', 'security', 'dice', 'le...
# (_remote_exec_multi_chain pid=404) 37139  ['kinaxis', 'solution', 'architect', 'dice', '...
# (_remote_exec_multi_chain pid=404) 37140  ['summer', 'save', 'sustain', 'life', 'baxter'...
# (_remote_exec_multi_chain pid=404)
# (_remote_exec_multi_chain pid=32032) 6608   ['teamcenter', 'infrastructure', 'architect', ...
# (_remote_exec_multi_chain pid=32032) 6609   ['fiber', 'splicer', 'location', 'work', 'pell...
# (_remote_exec_multi_chain pid=32032) 6610   ['senior', 'network', 'engineer', 'role', 'sen...
# (_remote_exec_multi_chain pid=32032) 6611   ['senior', 'cloud', 'developer', 'responsibili...
# (_remote_exec_multi_chain pid=32032) 6612   ['senior', 'software', 'engineer', 'backend', ...
# (_remote_exec_multi_chain pid=32032) 13101  ['game', 'developer', 'level', 'explore', 'exc...
# (_remote_exec_multi_chain pid=32032) 13102  ['cyber', 'security', 'analyst', 'utility', 'c...
# (_remote_exec_multi_chain pid=32032) 13103  ['cloud', 'devops', 'engineer', 'job', 'openin...
# (_remote_exec_multi_chain pid=32032) 13105  ['data', 'analyst', 'mdg', 'sap', 'data', 'ana...
# (_remote_exec_multi_chain pid=32032)
# (_remote_exec_multi_chain pid=32032) 6608     3995263927  ...  ['teamcenter', 'infrastructure', 'architect', ...
# (_remote_exec_multi_chain pid=32032) 6609     3995263795  ...  ['fiber', 'splicer', 'location', 'work', 'pell...
# (_remote_exec_multi_chain pid=32032) 6610     3995263759  ...  ['senior', 'network', 'engineer', 'role', 'sen...
# (_remote_exec_multi_chain pid=32032) 6611     3995263729  ...  ['senior', 'cloud', 'developer', 'responsibili...
# (_remote_exec_multi_chain pid=32032) 6612     3995263531  ...  ['senior', 'software', 'engineer', 'backend', ...
# (_remote_exec_multi_chain pid=32032) 13101    3824781949  ...  ['game', 'developer', 'level', 'explore', 'exc...
# (_remote_exec_multi_chain pid=32032) 13102    3824781133  ...  ['cyber', 'security', 'analyst', 'utility', 'c...
# (_remote_exec_multi_chain pid=32032) 13103    3824781097  ...  ['cloud', 'devops', 'engineer', 'job', 'openin...
# (_remote_exec_multi_chain pid=32032) 13105    3824780893  ...  ['data', 'analyst', 'mdg', 'sap', 'data', 'ana...
# (_remote_exec_multi_chain pid=32032)
# (_remote_exec_multi_chain pid=8800) 18784  ['geotechnical', 'engineering', 'manager', 'ch...
# (_remote_exec_multi_chain pid=8800) 18785  ['python', 'developer', 'company', 'descriptio...
# (_remote_exec_multi_chain pid=8800) 18786  ['manager', 'medium', 'customer', 'analytics',...
# (_remote_exec_multi_chain pid=8800) 18787  ['design', 'project', 'manager', 'kemp', 'cons...
# (_remote_exec_multi_chain pid=8800) 18788  ['remote', 'servicenow', 'hrsd', 'developer', ...
# (_remote_exec_multi_chain pid=8800) 27985  ['full', 'stack', 'developer', 'experience', '...
# (_remote_exec_multi_chain pid=8800) 27986  ['full', 'stack', 'engineer', 'experience', 'y...
# (_remote_exec_multi_chain pid=8800) 27987  ['full', 'stack', 'developer', 'node', 'j', 'r...
# (_remote_exec_multi_chain pid=8800) 27988  ['system', 'administrator', 'aboutcompanies', ...
# (_remote_exec_multi_chain pid=8800) 27989  ['full', 'stack', 'typescript', 'developer', '...
# (_remote_exec_multi_chain pid=8800)
# (_remote_exec_multi_chain pid=35296) 0     ['plaintext', 'john', 'doe', 'address', 'city'...
# (_remote_exec_multi_chain pid=35296) 3     ['plaintext', 'summary', 'highly', 'accomplish...
# (_remote_exec_multi_chain pid=35296) 4     ['plaintext', 'name', 'address', 'city', 'post...
# (_remote_exec_multi_chain pid=35296) 1238  ['markdown', 'john', 'doe', 'location', 'germa...
# (_remote_exec_multi_chain pid=35296) 1239  ['plaintext', 'name', 'address', 'city', 'post...
# (_remote_exec_multi_chain pid=35296) 1240  ['markdown', 'john', 'doe', 'address', 'city',...
# (_remote_exec_multi_chain pid=35296)
# (_remote_exec_multi_chain pid=2408) 2     ['markdown', 'summary', 'dynamic', 'profession...
# (_remote_exec_multi_chain pid=2408) 4     ['markdown', 'summary', 'highly', 'skilled', '...
# (_remote_exec_multi_chain pid=2408) 1232  ['plaintext', 'john', 'doe', 'location', 'pola...
# (_remote_exec_multi_chain pid=2408)
# (_remote_exec_multi_chain pid=2408) 2     ```markdown\n**Summary**  \nDynamic and result...  ...  ['markdown', 'summary', 'dynamic', 'profession...
# (_remote_exec_multi_chain pid=2408) 4     ```markdown\n**Summary**  \nHighly skilled and...  ...  ['markdown', 'summary', 'highly', 'skilled', '...
# (_remote_exec_multi_chain pid=2408) 1232  ```plaintext\n**John Doe**  \nLocation: Poland...  ...  ['plaintext', 'john', 'doe', 'location', 'pola...
# (_remote_exec_multi_chain pid=2408)
# (_remote_exec_multi_chain pid=12480)
# (_remote_exec_multi_chain pid=404) 27990    3823610023  ...  ['full', 'stack', 'engineer', 'sdk', 'node', '...
# (_remote_exec_multi_chain pid=404) 27991    3823609255  ...  ['system', 'administrator', 'role', 'system', ...
# (_remote_exec_multi_chain pid=404) 27992    3823608127  ...  ['devops', 'engineer', 'welcome', 'hastings', ...
# (_remote_exec_multi_chain pid=404) 27993    3823607845  ...  ['system', 'administrator', 'role', 'system', ...
# (_remote_exec_multi_chain pid=404) 27994    3823606981  ...  ['machine', 'learning', 'lead', 'analyst', 'ev...
# (_remote_exec_multi_chain pid=404) 37136    4051891921  ...  ['sap', 'digital', 'payment', 'integration', '...
# (_remote_exec_multi_chain pid=404) 37137    4051891795  ...  ['full', 'time', 'oracle', 'hcm', 'program', '...
# (_remote_exec_multi_chain pid=404) 37138    4051891765  ...  ['manager', 'network', 'security', 'dice', 'le...
# (_remote_exec_multi_chain pid=404) 37139    4051891747  ...  ['kinaxis', 'solution', 'architect', 'dice', '...
# (_remote_exec_multi_chain pid=404) 37140    4051891537  ...  ['summer', 'save', 'sustain', 'life', 'baxter'...
# (_remote_exec_multi_chain pid=404)
# (_remote_exec_multi_chain pid=8800) 18784    3908643051  ...  ['geotechnical', 'engineering', 'manager', 'ch...
# (_remote_exec_multi_chain pid=8800) 18785    3908642637  ...  ['python', 'developer', 'company', 'descriptio...
# (_remote_exec_multi_chain pid=8800) 18786    3908642601  ...  ['manager', 'medium', 'customer', 'analytics',...
# (_remote_exec_multi_chain pid=8800) 18787    3908641821  ...  ['design', 'project', 'manager', 'kemp', 'cons...
# (_remote_exec_multi_chain pid=8800) 18788    3908641563  ...  ['remote', 'servicenow', 'hrsd', 'developer', ...
# (_remote_exec_multi_chain pid=8800) 27985    3823619131  ...  ['full', 'stack', 'developer', 'experience', '...
# (_remote_exec_multi_chain pid=8800) 27986    3823619125  ...  ['full', 'stack', 'engineer', 'experience', 'y...
# (_remote_exec_multi_chain pid=8800) 27987    3823617265  ...  ['full', 'stack', 'developer', 'node', 'j', 'r...
# (_remote_exec_multi_chain pid=8800) 27988    3823616785  ...  ['system', 'administrator', 'aboutcompanies', ...
# (_remote_exec_multi_chain pid=8800) 27989    3823616023  ...  ['full', 'stack', 'typescript', 'developer', '...
# (_remote_exec_multi_chain pid=8800)
# (_remote_exec_multi_chain pid=35296) 0     ```plaintext\nJohn Doe  \n[Your Address]  \n[C...  ...  ['plaintext', 'john', 'doe', 'address', 'city'...
# (_remote_exec_multi_chain pid=35296) 2     **Summary**\n\nDynamic and results-driven soft...  ...  ['summary', 'dynamic', 'software', 'developer'...
# (_remote_exec_multi_chain pid=35296) 3     ```plaintext\n**Summary**  \nA highly accompli...  ...  ['plaintext', 'summary', 'highly', 'accomplish...
# (_remote_exec_multi_chain pid=35296) 4     ```plaintext\n**[Your Name]**  \n[Your Address...  ...  ['plaintext', 'name', 'address', 'city', 'post...
# (_remote_exec_multi_chain pid=35296) 1238  ```markdown\n**John Doe**  \nLocation: Germany...  ...  ['markdown', 'john', 'doe', 'location', 'germa...
# (_remote_exec_multi_chain pid=35296) 1239  ```plaintext\n[Your Name]  \n[Your Address]  \...  ...  ['plaintext', 'name', 'address', 'city', 'post...
# (_remote_exec_multi_chain pid=35296) 1240  ```markdown\n**John Doe**  \n[Your Address]  \...  ...  ['markdown', 'john', 'doe', 'address', 'city',...
# (_remote_exec_multi_chain pid=35296)
# (_remote_exec_multi_chain pid=15644) 4     ['name', 'address', 'city', 'province', 'posta...
# (_remote_exec_multi_chain pid=15644) 1223  ['markdown', 'name', 'address', 'city', 'state...
# (_remote_exec_multi_chain pid=15644) 1225  ['json', 'summary', 'dynamic', 'software', 'en...
# (_remote_exec_multi_chain pid=15644)
# (_remote_exec_multi_chain pid=12480) 1     ```plaintext\n**Summary**  \nResults-driven an...  ...  ['plaintext', 'summary', 'highly', 'skilled', ...
# (_remote_exec_multi_chain pid=12480) 4     **Resume**\n\n---\n\n**Summary**\n\nDynamic an...  ...  ['resume', 'summary', 'dynamic', 'software', '...
# (_remote_exec_multi_chain pid=12480) 1221  ```plaintext\n**Summary**\n\nDynamic and resul...  ...  ['plaintext', 'summary', 'dynamic', 'software'...
# (_remote_exec_multi_chain pid=12480) 1224  # Resume\n\n## Summary\nDynamic and results-dr...  ...  ['resume', 'summary', 'dynamic', 'software', '...
# (_remote_exec_multi_chain pid=12480)
# (_remote_exec_multi_chain pid=36764) 9054   ['site', 'reliability', 'engineer', 'netnod', ...
# (_remote_exec_multi_chain pid=36764) 9055   ['devops', 'engineer', 'considered', 'position...
# (_remote_exec_multi_chain pid=36764) 9056   ['principal', 'business', 'data', 'analyst', '...
# (_remote_exec_multi_chain pid=36764) 9057   ['system', 'administrator', 'job', 'descriptio...
# (_remote_exec_multi_chain pid=36764) 9058   ['data', 'scientist', 'specialist', 'nlp', 'll...
# (_remote_exec_multi_chain pid=36764) 18779  ['training', 'client', 'service', 'training', ...
# (_remote_exec_multi_chain pid=36764) 18780  ['senior', 'software', 'developer', 'java', 'n...
# (_remote_exec_multi_chain pid=36764) 18781  ['senior', 'software', 'engineer', 'window', '...
# (_remote_exec_multi_chain pid=36764) 18782  ['microbiology', 'manager', 'arsenale', 'bioya...
# (_remote_exec_multi_chain pid=36764) 18783  ['data', 'warehouse', 'architect', 'seeking', ...
# (_remote_exec_multi_chain pid=36764)
# (_remote_exec_multi_chain pid=36764) 9054     3965530308  ...  ['site', 'reliability', 'engineer', 'netnod', ...
# (_remote_exec_multi_chain pid=36764) 9055     3965530002  ...  ['devops', 'engineer', 'considered', 'position...
# (_remote_exec_multi_chain pid=36764) 9056     3965527770  ...  ['principal', 'business', 'data', 'analyst', '...
# (_remote_exec_multi_chain pid=36764) 9057     3965527698  ...  ['system', 'administrator', 'job', 'descriptio...
# (_remote_exec_multi_chain pid=36764) 9058     3965527158  ...  ['data', 'scientist', 'specialist', 'nlp', 'll...
# (_remote_exec_multi_chain pid=36764) 18779    3908651763  ...  ['training', 'client', 'service', 'training', ...
# (_remote_exec_multi_chain pid=36764) 18780    3908651721  ...  ['senior', 'software', 'developer', 'java', 'n...
# (_remote_exec_multi_chain pid=36764) 18781    3908649243  ...  ['senior', 'software', 'engineer', 'window', '...
# (_remote_exec_multi_chain pid=36764) 18782    3908648025  ...  ['microbiology', 'manager', 'arsenale', 'bioya...
# (_remote_exec_multi_chain pid=36764) 18783    3908643969  ...  ['data', 'warehouse', 'architect', 'seeking', ...
# (_remote_exec_multi_chain pid=36764)
# (_remote_exec_multi_chain pid=15644) 4     **[Your Name]**  \n[Your Address] | [City, Pro...  ...  ['name', 'address', 'city', 'province', 'posta...
# (_remote_exec_multi_chain pid=15644) 1223  ```markdown\n**[Your Name]**  \n[Your Address]...  ...  ['markdown', 'name', 'address', 'city', 'state...
# (_remote_exec_multi_chain pid=15644) 1225  ```json\n{\n  "Summary": "Dynamic and results-...  ...  ['json', 'summary', 'dynamic', 'software', 'en...
# (_remote_exec_multi_chain pid=15644) 1227  ```markdown\n# Summary\nDynamic and motivated ...  ...  ['markdown', 'summary', 'dynamic', 'motivated'...
# (_remote_exec_multi_chain pid=15644)

# %%
cvs_df = pd.read_csv("../User Data/cvs_tokenized_final.csv")
cvs_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             CV  \
# 0                                                                                                                             ```plaintext\n**Summary**  \nDynamic and detail-oriented software engineer with 12-14 years of progressive experience in developing robust applications using a variety of programming languages including TypeScript, SQL, and Java. Proven expertise in leveraging web and database technologies such as Node.js, ASP.NET Core, Firebase, and MongoDB. Highly adept in employing modern frameworks and tools to streamline development processes and enhance application performance. Committed to delivering innovative solutions and continuous improvement in the software development lifecycle.\n\n**Skills**  \n- **Programming Languages:** TypeScript, SQL, Java  \n- **Databases:** Firebase, MongoDB  \n- **Web Frameworks:** Node.js, ASP.NET Core  \n- **Other Frameworks:** .NET, Keras  \n- **Tools:** Git, Ansible  \n- **IDEs:** Sublime Text, IntelliJ  \n- **Operating Systems:** Windows, macOS  \n\n**Experience**  \n- Developed and maintained complex software applications, leading projects from conception through deployment.  \n- Collaborated with cross-functional teams to design and implement scalable solutions, enhancing user experience and operational efficiency.  \n- Utilized TypeScript and SQL for backend services and database management, demonstrating fluency in data-driven application development.  \n- Leveraged frameworks such as Node.js and ASP.NET Core to build responsive web applications, driving increased engagement and usability.  \n- Implemented CI/CD practices using Git and Ansible, resulting in improved deployment times and reduced rollout errors.  \n\n**Education**  \nBachelorâ€™s Degree in Computer Science  \n[Your University Name]  \n[Year of Graduation]  \nBrazil  \n```
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ```plaintext\n**Summary:**\nDynamic and results-driven software engineer with over 15 years of comprehensive experience in developing and implementing scalable web applications. Proficient in a diverse range of programming languages and technologies, with a strong focus on delivering efficient solutions. Seeking to leverage extensive knowledge in modern frameworks and database management in a challenging role within an innovative team.\n\n**Skills:**\n- **Programming Languages:** C#, SQL, JavaScript\n- **Databases:** MongoDB, MySQL\n- **Web Frameworks:** Angular, React.js\n- **Other Frameworks:** NumPy, .NET\n- **Tools:** Docker, Vagrant\n- **IDEs:** Visual Studio, Atom\n- **Operating Systems:** macOS, Windows\n\n**Experience:**\n- Over 15 years of professional experience in software development and project management.\n- Proven track record of successfully delivering full-stack applications using Angular and React.js integrated with both MongoDB and MySQL databases.\n- Collaborated with cross-functional teams to enhance user experience and optimize application performance.\n- Expertise in leveraging containerization and virtualization tools such as Docker and Vagrant to streamline development processes.\n\n**Education:**\n- Bachelorâ€™s Degree in Computer Science (or relevant field)\n```
# 2                                                                                                                                                                                                                                                                                                              ```plaintext\n**Summary**  \nDedicated and skilled female software developer with 6-8 years of comprehensive experience in designing and implementing innovative solutions. Proficient in leveraging a diverse range of programming languages and frameworks to enhance web applications and data management. Adept at collaborating in dynamic environments, driving project success through solid technical expertise, and a passion for progressing in the tech industry.\n\n**Skills**  \n- **Programming Languages:** SQL, HTML/CSS, PHP  \n- **Databases:** Firebase, PostgreSQL  \n- **Web Frameworks:** Django, ASP.NET Core  \n- **Other Frameworks:** React Native, Pandas  \n- **Other Tools:** Kubernetes, Webpack  \n- **IDEs:** Visual Studio Code, IntelliJ  \n- **Operating Systems:** macOS, Linux  \n\n**Experience**  \n- Developed and maintained dynamic web applications, utilizing Django and ASP.NET Core for back-end development, ensuring optimal performance and user engagement.\n- Architected and managed databases using PostgreSQL and Firebase, enhancing data integrity and retrieval processes.\n- Implemented responsive front-end solutions using HTML/CSS and React Native, improving the user experience across various devices.\n- Collaborated with cross-functional teams to deploy applications via Kubernetes, streamlining the deployment process and enhancing scalability.\n\n**Education**  \nBachelorâ€™s Degree in Computer Science (or relevant field)  \n[Your University Name] | [Graduation Year] | United States  \n```
# 3  ```markdown\n**Summary**  \nDynamic and detail-oriented software developer with a Bachelorâ€™s degree and 1-2 years of experience in building robust web applications. Proficient in various programming languages and frameworks, with a strong focus on efficient code and user experience. Demonstrates excellent problem-solving skills and the ability to work collaboratively in diverse team environments, bringing a proactive approach to development and deployment processes.\n\n**Skills**  \n- **Programming Languages:** TypeScript, Java, JavaScript  \n- **Databases:** Firebase, MariaDB  \n- **Web Frameworks:** React.js, Node.js  \n- **Other Frameworks:** React Native, .NET  \n- **Tools:** Docker, Ansible  \n- **IDEs:** Visual Studio Code, Visual Studio  \n- **Operating Systems:** Windows, Linux  \n\n**Experience**  \n*Software Developer*  \n[Your Company Name] â€” Poland  \n[Month, Year] to Present  \n- Developed and maintained applications utilizing React.js and Node.js, enhancing user interaction and experience.  \n- Collaborated with cross-functional teams to design and implement responsive web solutions, ensuring seamless integration with back-end services.  \n- Worked extensively with databases like Firebase and MariaDB, optimizing data storage and retrieval processes.  \n- Engaged in continuous learning and adoption of best practices in software development, contributing to team knowledge and resourcefulness.\n\n**Education**  \n*Bachelorâ€™s Degree in [Your Major]*  \n[Your University Name] â€” [Year of Graduation]  \n- Completed foundational coursework in computer science, focusing on software development methodologies and modern programming techniques.  \n- Participated in various team projects that reinforced collaborative skills and practical application of theoretical knowledge.\n```
# 4                                                                                                                                                                                                           ```plaintext\n**Summary**  \nDynamic and detail-oriented software developer with a Masterâ€™s degree and over three years of experience in software development. Proficient in multiple programming languages including Java, JavaScript, and C#. Demonstrates a strong ability to design and build efficient applications using a variety of frameworks and tools, while delivering high-quality code. Based in France, ready to leverage expertise in development and database management to drive innovative solutions.\n\n**Skills**  \n- **Programming Languages**: Java, JavaScript, C#  \n- **Databases**: MySQL, Redis  \n- **Web Frameworks**: Angular, Django  \n- **Other Frameworks**: NumPy, .NET  \n- **Other Tools**: Ansible, Chef  \n- **IDEs**: Visual Studio Code, IntelliJ  \n- **Operating Systems**: Windows, Linux  \n\n**Experience**  \n- **Software Developer** (3-5 years)  \n  - Developed robust applications using Java and C#, enhancing the user experience through efficient coding practices.\n  - Leveraged Angular for dynamic web application interfaces and utilized Django for server-side logic, contributing to full-stack development projects.\n  - Managed database operations with MySQL and Redis, ensuring optimal data retrieval and storage solutions.\n  - Implemented continuous integration and delivery pipelines using Ansible and Chef to streamline development processes.\n\n**Education**  \n- **Masterâ€™s Degree in Computer Science**  \n  - Focused on software engineering principles, data structures, and database management, providing a solid foundation for technical expertise in software development.\n```
#
#    gender  \
# 0  female
# 1  female
# 2  female
# 3  female
# 4  female
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           text  \
# 0                                                                                                                             ```plaintext\n**Summary**  \nDynamic and detail-oriented software engineer with 12-14 years of progressive experience in developing robust applications using a variety of programming languages including TypeScript, SQL, and Java. Proven expertise in leveraging web and database technologies such as Node.js, ASP.NET Core, Firebase, and MongoDB. Highly adept in employing modern frameworks and tools to streamline development processes and enhance application performance. Committed to delivering innovative solutions and continuous improvement in the software development lifecycle.\n\n**Skills**  \n- **Programming Languages:** TypeScript, SQL, Java  \n- **Databases:** Firebase, MongoDB  \n- **Web Frameworks:** Node.js, ASP.NET Core  \n- **Other Frameworks:** .NET, Keras  \n- **Tools:** Git, Ansible  \n- **IDEs:** Sublime Text, IntelliJ  \n- **Operating Systems:** Windows, macOS  \n\n**Experience**  \n- Developed and maintained complex software applications, leading projects from conception through deployment.  \n- Collaborated with cross-functional teams to design and implement scalable solutions, enhancing user experience and operational efficiency.  \n- Utilized TypeScript and SQL for backend services and database management, demonstrating fluency in data-driven application development.  \n- Leveraged frameworks such as Node.js and ASP.NET Core to build responsive web applications, driving increased engagement and usability.  \n- Implemented CI/CD practices using Git and Ansible, resulting in improved deployment times and reduced rollout errors.  \n\n**Education**  \nBachelorâ€™s Degree in Computer Science  \n[Your University Name]  \n[Year of Graduation]  \nBrazil  \n```
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ```plaintext\n**Summary:**\nDynamic and results-driven software engineer with over 15 years of comprehensive experience in developing and implementing scalable web applications. Proficient in a diverse range of programming languages and technologies, with a strong focus on delivering efficient solutions. Seeking to leverage extensive knowledge in modern frameworks and database management in a challenging role within an innovative team.\n\n**Skills:**\n- **Programming Languages:** C#, SQL, JavaScript\n- **Databases:** MongoDB, MySQL\n- **Web Frameworks:** Angular, React.js\n- **Other Frameworks:** NumPy, .NET\n- **Tools:** Docker, Vagrant\n- **IDEs:** Visual Studio, Atom\n- **Operating Systems:** macOS, Windows\n\n**Experience:**\n- Over 15 years of professional experience in software development and project management.\n- Proven track record of successfully delivering full-stack applications using Angular and React.js integrated with both MongoDB and MySQL databases.\n- Collaborated with cross-functional teams to enhance user experience and optimize application performance.\n- Expertise in leveraging containerization and virtualization tools such as Docker and Vagrant to streamline development processes.\n\n**Education:**\n- Bachelorâ€™s Degree in Computer Science (or relevant field)\n```
# 2                                                                                                                                                                                                                                                                                                              ```plaintext\n**Summary**  \nDedicated and skilled female software developer with 6-8 years of comprehensive experience in designing and implementing innovative solutions. Proficient in leveraging a diverse range of programming languages and frameworks to enhance web applications and data management. Adept at collaborating in dynamic environments, driving project success through solid technical expertise, and a passion for progressing in the tech industry.\n\n**Skills**  \n- **Programming Languages:** SQL, HTML/CSS, PHP  \n- **Databases:** Firebase, PostgreSQL  \n- **Web Frameworks:** Django, ASP.NET Core  \n- **Other Frameworks:** React Native, Pandas  \n- **Other Tools:** Kubernetes, Webpack  \n- **IDEs:** Visual Studio Code, IntelliJ  \n- **Operating Systems:** macOS, Linux  \n\n**Experience**  \n- Developed and maintained dynamic web applications, utilizing Django and ASP.NET Core for back-end development, ensuring optimal performance and user engagement.\n- Architected and managed databases using PostgreSQL and Firebase, enhancing data integrity and retrieval processes.\n- Implemented responsive front-end solutions using HTML/CSS and React Native, improving the user experience across various devices.\n- Collaborated with cross-functional teams to deploy applications via Kubernetes, streamlining the deployment process and enhancing scalability.\n\n**Education**  \nBachelorâ€™s Degree in Computer Science (or relevant field)  \n[Your University Name] | [Graduation Year] | United States  \n```
# 3  ```markdown\n**Summary**  \nDynamic and detail-oriented software developer with a Bachelorâ€™s degree and 1-2 years of experience in building robust web applications. Proficient in various programming languages and frameworks, with a strong focus on efficient code and user experience. Demonstrates excellent problem-solving skills and the ability to work collaboratively in diverse team environments, bringing a proactive approach to development and deployment processes.\n\n**Skills**  \n- **Programming Languages:** TypeScript, Java, JavaScript  \n- **Databases:** Firebase, MariaDB  \n- **Web Frameworks:** React.js, Node.js  \n- **Other Frameworks:** React Native, .NET  \n- **Tools:** Docker, Ansible  \n- **IDEs:** Visual Studio Code, Visual Studio  \n- **Operating Systems:** Windows, Linux  \n\n**Experience**  \n*Software Developer*  \n[Your Company Name] â€” Poland  \n[Month, Year] to Present  \n- Developed and maintained applications utilizing React.js and Node.js, enhancing user interaction and experience.  \n- Collaborated with cross-functional teams to design and implement responsive web solutions, ensuring seamless integration with back-end services.  \n- Worked extensively with databases like Firebase and MariaDB, optimizing data storage and retrieval processes.  \n- Engaged in continuous learning and adoption of best practices in software development, contributing to team knowledge and resourcefulness.\n\n**Education**  \n*Bachelorâ€™s Degree in [Your Major]*  \n[Your University Name] â€” [Year of Graduation]  \n- Completed foundational coursework in computer science, focusing on software development methodologies and modern programming techniques.  \n- Participated in various team projects that reinforced collaborative skills and practical application of theoretical knowledge.\n```
# 4                                                                                                                                                                                                           ```plaintext\n**Summary**  \nDynamic and detail-oriented software developer with a Masterâ€™s degree and over three years of experience in software development. Proficient in multiple programming languages including Java, JavaScript, and C#. Demonstrates a strong ability to design and build efficient applications using a variety of frameworks and tools, while delivering high-quality code. Based in France, ready to leverage expertise in development and database management to drive innovative solutions.\n\n**Skills**  \n- **Programming Languages**: Java, JavaScript, C#  \n- **Databases**: MySQL, Redis  \n- **Web Frameworks**: Angular, Django  \n- **Other Frameworks**: NumPy, .NET  \n- **Other Tools**: Ansible, Chef  \n- **IDEs**: Visual Studio Code, IntelliJ  \n- **Operating Systems**: Windows, Linux  \n\n**Experience**  \n- **Software Developer** (3-5 years)  \n  - Developed robust applications using Java and C#, enhancing the user experience through efficient coding practices.\n  - Leveraged Angular for dynamic web application interfaces and utilized Django for server-side logic, contributing to full-stack development projects.\n  - Managed database operations with MySQL and Redis, ensuring optimal data retrieval and storage solutions.\n  - Implemented continuous integration and delivery pipelines using Ansible and Chef to streamline development processes.\n\n**Education**  \n- **Masterâ€™s Degree in Computer Science**  \n  - Focused on software engineering principles, data structures, and database management, providing a solid foundation for technical expertise in software development.\n```
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             tokens
# 0                                                                                                                         ['plaintext', 'summary', 'dynamic', 'software', 'engineer', 'year', 'progressive', 'experience', 'developing', 'robust', 'application', 'using', 'variety', 'programming', 'language', 'including', 'typescript', 'sql', 'java', 'proven', 'expertise', 'leveraging', 'web', 'database', 'technology', 'core', 'firebase', 'mongodb', 'highly', 'adept', 'employing', 'modern', 'framework', 'tool', 'streamline', 'development', 'process', 'enhance', 'application', 'performance', 'committed', 'delivering', 'innovative', 'solution', 'continuous', 'improvement', 'software', 'development', 'lifecycle', 'skill', 'programming', 'language', 'typescript', 'sql', 'java', 'database', 'firebase', 'mongodb', 'web', 'framework', 'core', 'framework', 'kera', 'tool', 'git', 'ansible', 'ides', 'sublime', 'text', 'intellij', 'operating', 'system', 'window', 'macos', 'experience', 'developed', 'maintained', 'complex', 'software', 'application', 'leading', 'project', 'conception', 'deployment', 'collaborated', 'team', 'design', 'implement', 'scalable', 'solution', 'enhancing', 'user', 'experience', 'operational', 'efficiency', 'utilized', 'typescript', 'sql', 'backend', 'service', 'database', 'management', 'demonstrating', 'fluency', 'application', 'development', 'leveraged', 'framework', 'core', 'build', 'responsive', 'web', 'application', 'driving', 'increased', 'engagement', 'usability', 'implemented', 'practice', 'using', 'git', 'ansible', 'resulting', 'improved', 'deployment', 'time', 'reduced', 'rollout', 'error', 'education', 'bachelor', 'degree', 'computer', 'science', 'university', 'name', 'year', 'graduation', 'brazil']
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ['plaintext', 'summary', 'dynamic', 'software', 'engineer', 'year', 'comprehensive', 'experience', 'developing', 'implementing', 'scalable', 'web', 'application', 'proficient', 'diverse', 'range', 'programming', 'language', 'technology', 'strong', 'focus', 'delivering', 'efficient', 'solution', 'seeking', 'leverage', 'extensive', 'knowledge', 'modern', 'framework', 'database', 'management', 'challenging', 'role', 'within', 'innovative', 'team', 'skill', 'programming', 'language', 'c', 'sql', 'javascript', 'database', 'mongodb', 'mysql', 'web', 'framework', 'angular', 'framework', 'numpy', 'tool', 'docker', 'vagrant', 'ides', 'visual', 'studio', 'atom', 'operating', 'system', 'macos', 'window', 'experience', 'year', 'professional', 'experience', 'software', 'development', 'project', 'management', 'proven', 'track', 'record', 'successfully', 'delivering', 'application', 'using', 'angular', 'integrated', 'mongodb', 'mysql', 'database', 'collaborated', 'team', 'enhance', 'user', 'experience', 'optimize', 'application', 'performance', 'expertise', 'leveraging', 'containerization', 'virtualization', 'tool', 'docker', 'vagrant', 'streamline', 'development', 'process', 'education', 'bachelor', 'degree', 'computer', 'science', 'relevant', 'field']
# 2                                                                                                                                                                                                                                                   ['plaintext', 'summary', 'dedicated', 'skilled', 'female', 'software', 'developer', 'year', 'comprehensive', 'experience', 'designing', 'implementing', 'innovative', 'solution', 'proficient', 'leveraging', 'diverse', 'range', 'programming', 'language', 'framework', 'enhance', 'web', 'application', 'data', 'management', 'adept', 'collaborating', 'dynamic', 'environment', 'driving', 'project', 'success', 'solid', 'technical', 'expertise', 'passion', 'progressing', 'tech', 'industry', 'skill', 'programming', 'language', 'sql', 'php', 'database', 'firebase', 'postgresql', 'web', 'framework', 'django', 'core', 'framework', 'react', 'native', 'panda', 'tool', 'kubernetes', 'webpack', 'ides', 'visual', 'studio', 'code', 'intellij', 'operating', 'system', 'macos', 'linux', 'experience', 'developed', 'maintained', 'dynamic', 'web', 'application', 'utilizing', 'django', 'core', 'development', 'ensuring', 'optimal', 'performance', 'user', 'engagement', 'architected', 'managed', 'database', 'using', 'postgresql', 'firebase', 'enhancing', 'data', 'integrity', 'retrieval', 'process', 'implemented', 'responsive', 'solution', 'using', 'react', 'native', 'improving', 'user', 'experience', 'across', 'various', 'device', 'collaborated', 'team', 'deploy', 'application', 'via', 'kubernetes', 'streamlining', 'deployment', 'process', 'enhancing', 'scalability', 'education', 'bachelor', 'degree', 'computer', 'science', 'relevant', 'field', 'university', 'name', 'graduation', 'year', 'united', 'state']
# 3  ['markdown', 'summary', 'dynamic', 'software', 'developer', 'bachelor', 'degree', 'year', 'experience', 'building', 'robust', 'web', 'application', 'proficient', 'various', 'programming', 'language', 'framework', 'strong', 'focus', 'efficient', 'code', 'user', 'experience', 'demonstrates', 'excellent', 'skill', 'ability', 'work', 'collaboratively', 'diverse', 'team', 'environment', 'bringing', 'proactive', 'approach', 'development', 'deployment', 'process', 'skill', 'programming', 'language', 'typescript', 'java', 'javascript', 'database', 'firebase', 'mariadb', 'web', 'framework', 'framework', 'react', 'native', 'tool', 'docker', 'ansible', 'ides', 'visual', 'studio', 'code', 'visual', 'studio', 'operating', 'system', 'window', 'linux', 'experience', 'software', 'developer', 'company', 'name', 'poland', 'month', 'year', 'present', 'developed', 'maintained', 'application', 'utilizing', 'enhancing', 'user', 'interaction', 'experience', 'collaborated', 'team', 'design', 'implement', 'responsive', 'web', 'solution', 'ensuring', 'seamless', 'integration', 'service', 'worked', 'extensively', 'database', 'like', 'firebase', 'mariadb', 'optimizing', 'data', 'storage', 'retrieval', 'process', 'engaged', 'continuous', 'learning', 'adoption', 'best', 'practice', 'software', 'development', 'contributing', 'team', 'knowledge', 'resourcefulness', 'education', 'bachelor', 'degree', 'major', 'university', 'name', 'year', 'graduation', 'completed', 'foundational', 'coursework', 'computer', 'science', 'focusing', 'software', 'development', 'methodology', 'modern', 'programming', 'technique', 'participated', 'various', 'team', 'project', 'reinforced', 'collaborative', 'skill', 'practical', 'application', 'theoretical', 'knowledge']
# 4                                                                                                                                                 ['plaintext', 'summary', 'dynamic', 'software', 'developer', 'master', 'degree', 'three', 'year', 'experience', 'software', 'development', 'proficient', 'multiple', 'programming', 'language', 'including', 'java', 'javascript', 'c', 'demonstrates', 'strong', 'ability', 'design', 'build', 'efficient', 'application', 'using', 'variety', 'framework', 'tool', 'delivering', 'code', 'based', 'france', 'ready', 'leverage', 'expertise', 'development', 'database', 'management', 'drive', 'innovative', 'solution', 'skill', 'programming', 'language', 'java', 'javascript', 'c', 'database', 'mysql', 'redis', 'web', 'framework', 'angular', 'django', 'framework', 'numpy', 'tool', 'ansible', 'chef', 'ides', 'visual', 'studio', 'code', 'intellij', 'operating', 'system', 'window', 'linux', 'experience', 'software', 'developer', 'year', 'developed', 'robust', 'application', 'using', 'java', 'c', 'enhancing', 'user', 'experience', 'efficient', 'coding', 'practice', 'leveraged', 'angular', 'dynamic', 'web', 'application', 'interface', 'utilized', 'django', 'logic', 'contributing', 'development', 'project', 'managed', 'database', 'operation', 'mysql', 'redis', 'ensuring', 'optimal', 'data', 'retrieval', 'storage', 'solution', 'implemented', 'continuous', 'integration', 'delivery', 'pipeline', 'using', 'ansible', 'chef', 'streamline', 'development', 'process', 'education', 'master', 'degree', 'computer', 'science', 'focused', 'software', 'engineering', 'principle', 'data', 'structure', 'database', 'management', 'providing', 'solid', 'foundation', 'technical', 'expertise', 'software', 'development']

# %%
# Train Word2Vec model with CBOW (sg=0) and bigrams
w2v_model = Word2Vec(sentences=job_postings_df['tokens'], vector_size=100, window=5, min_count=2, sg=0, workers=4)

# Get the word vectors
word_vectors = w2v_model.wv

# %%
# Vectorize both job postings and CVs using the new bigram model
job_postings_df['vector'] = job_postings_df['tokens'].apply(lambda tokens: vectorize_text(tokens, w2v_model))
cvs_df['vector'] = cvs_df['tokens'].apply(lambda tokens: vectorize_text(tokens, w2v_model))

# %%
# Get the vectors
job_vectors = np.vstack(job_postings_df['vector'])
cv_vectors = np.vstack(cvs_df['vector'])

# %%
# Compute cosine similarity between CVs and job postings
similarities = cosine_similarity(cv_vectors, job_vectors)

# %%
# Get the top N most similar jobs for each CV
top_n = 10
top_indices = np.argsort(-similarities, axis=1)[:, :top_n]

# %%
all_recommendations = []
for cv_idx, job_idxs in tqdm(enumerate(top_indices)):
    for rank, job_idx in enumerate(job_idxs, start=1):  # Start rank from 1
        recs = job_postings_df.iloc[job_idx][['jobPostingId', 'title', 'description', 'gender_category']].copy()
        recs = recs.reset_index(drop=True) 
        recs['rank'] = rank 
        recs['cv_index'] = cv_idx           # Track which CV this is for
        recs['CV'] = cvs_df.iloc[cv_idx]['CV']
        recs['applicant_gender'] = cvs_df.iloc[cv_idx]['gender']
        all_recommendations.append(recs)

# %%
# Create a DataFrame with the recommendations
recommendations_df = pd.DataFrame(all_recommendations)
recommendations_df = recommendations_df.rename(columns = {0: 'jobPostingId', 1:'title', 2:'description', 3:'gender_category'})
recommendations_df.head()

# %%
# recommendations_df = pd.concat(all_recommendations, ignore_index=True)
cols = [ 'cv_index', 'CV', 'applicant_gender', 'jobPostingId', 'title', 'description', 'gender_category', 'rank']
recommendations_df = recommendations_df[cols] 
recommendations_df.head(10)

# %%
recommendations_df.to_csv(f'../Recommendation Data/word2vec_cbow_{len(recommendations_df)}_penalty.csv', index = False)
